# %% [markdown]
# Nhiệm vụ 3 – GroupBy & Tổng hợp

# %%
#đọc dữ liệu
import pandas as pd
import numpy as np

citizen_df = pd.read_csv("../data_clean/citizen_info_clean.csv")
feedback_df = pd.read_csv("../data_clean/feedback_log_clean.csv")
resolution_df = pd.read_csv("../data_clean/resolution_time_clean.csv")

feedback_df['submit_time'] = pd.to_datetime(feedback_df['submit_time'])
resolution_df['resolved_time'] = pd.to_datetime(resolution_df['resolved_time'])

# %%
#3.1 Số lượng phản ánh trung bình theo area

    #Gộp feedback với area
feedback_area = feedback_df.merge(
    citizen_df[['citizen_id', 'area']],
    on='citizen_id',
    how='left'
)
#đếm phản ánh theo area x category
area_category_count = (
    feedback_area
    .groupby(['area', 'category'])
    .size()
    .reset_index(name='feedback_count')
)
 # tính trung bình theo area
avg_feedback_area_category = (
    area_category_count
    .groupby('area')['feedback_count']
    .mean()
    .reset_index(name='avg_feedback_per_category')
    .sort_values('avg_feedback_per_category', ascending=False)
)

avg_feedback_area_category
# Out:
#        area  avg_feedback_per_category
# 2    quan 1                   2.375000
# 3    quận 1                   1.555556
# 4     xa  b                   1.500000
# 0  phuong a                   1.375000
# 6      xã b                   1.166667
# 1  phường a                   1.000000
# 5      xa b                   1.000000

# %%
#3.2 thời gian xử lý trung bình theo department
#Gộp feedback + resolution
feedback_resolution = feedback_df.merge(
    resolution_df[['feedback_id', 'resolution_hours']],
    on='feedback_id',
    how='left'
)
#Groupby department
avg_resolution_by_department = (
    feedback_resolution
    .groupby('department')['resolution_hours']
    .mean()
    .reset_index(name='avg_resolution_hours')
    .sort_values('avg_resolution_hours', ascending=False)
)

avg_resolution_by_department
# Out:
#      department  avg_resolution_hours
# 4    phong tnmt             57.000000
# 3   phong  tnmt             39.555556
# 8   ubnd phường             39.333333
# 1       cong an             33.333333
# 5    phòng tnmt             31.200000
# 2       công an             22.000000
# 6  ubnd  phuong             15.600000
# 7   ubnd phuong             13.600000
# 0      cong  an             13.000000

# %%
#3.3Thời gian xử lý trung bình theo department × category
avg_resolution_dept_category = (
    feedback_resolution
    .groupby(['department', 'category'])['resolution_hours']
    .mean()
    .reset_index(name='avg_resolution_hours')
    .sort_values('avg_resolution_hours', ascending=False)
)

avg_resolution_dept_category
# Out:
#       department            category  avg_resolution_hours
# 57   ubnd phường          moi truong             72.000000
# 33    phòng tnmt             an ninh             72.000000
# 30    phong tnmt             ha tang             72.000000
# 20   phong  tnmt             an ninh             72.000000
# 9        cong an             hạ tầng             72.000000
# 40    phòng tnmt  thủ tục hành chính             72.000000
# 56   ubnd phường             hạ tầng             72.000000
# 28    phong tnmt            an  ninh             52.000000
# 21   phong  tnmt            ha  tang             48.000000
# 7        cong an            an  ninh             48.000000
# 38    phòng tnmt          môi trường             40.000000
# 26   phong  tnmt             thu tuc             38.000000
# 12       công an             an ninh             38.000000
# 25   phong  tnmt          môi trường             33.333333
# 8        cong an             ha tang             29.000000
# 41  ubnd  phuong            an  ninh             28.000000
# 1       cong  an             an ninh             24.000000
# 34    phòng tnmt            ha  tang             24.000000
# 49   ubnd phuong             ha tang             24.000000
# 36    phòng tnmt             hạ tầng             24.000000
# 47   ubnd phuong             an ninh             14.000000
# 42  ubnd  phuong            ha  tang             13.000000
# 39    phòng tnmt             thu tuc             12.000000
# 6       cong  an  thủ tục hành chính             12.000000
# 23   phong  tnmt             hạ tầng             12.000000
# 37    phòng tnmt          moi truong              9.333333
# 4       cong  an          môi trường              8.000000
# 3       cong  an          moi truong              8.000000
# 10       cong an             thu tuc              8.000000
# 55   ubnd phường            ha  tang              8.000000
# 15       công an             hạ tầng              8.000000
# 52   ubnd phuong             thu tuc              8.000000
# 46  ubnd  phuong  thủ tục hành chính              8.000000
# 50   ubnd phuong          moi truong              8.000000
# 58   ubnd phường          môi trường              6.000000
# 18       công an  thủ tục hành chính              4.000000
# 45  ubnd  phuong          môi trường              4.000000
# 0       cong  an            an  ninh                   NaN
# 2       cong  an             ha tang                   NaN
# 5       cong  an             thu tuc                   NaN
# 11       công an            an  ninh                   NaN
# 13       công an            ha  tang                   NaN
# 14       công an             ha tang                   NaN
# 16       công an          môi trường                   NaN
# 17       công an             thu tuc                   NaN
# 19   phong  tnmt            an  ninh                   NaN
# 22   phong  tnmt             ha tang                   NaN
# 24   phong  tnmt          moi truong                   NaN
# 27   phong  tnmt  thủ tục hành chính                   NaN
# 29    phong tnmt            ha  tang                   NaN
# 31    phong tnmt             hạ tầng                   NaN
# 32    phong tnmt             thu tuc                   NaN
# 35    phòng tnmt             ha tang                   NaN
# 43  ubnd  phuong             ha tang                   NaN
# 44  ubnd  phuong          moi truong                   NaN
# 48   ubnd phuong            ha  tang                   NaN
# 51   ubnd phuong          môi trường                   NaN
# 53   ubnd phường            an  ninh                   NaN
# 54   ubnd phường             an ninh                   NaN

# %%
#3.4So sánh thời gian xử lý trung bình giữa các channel
avg_resolution_by_channel = (
    feedback_resolution
    .groupby('channel')['resolution_hours']
    .mean()
    .reset_index(name='avg_resolution_hours')
    .sort_values('avg_resolution_hours', ascending=False)
)

avg_resolution_by_channel
# Out:
#      channel  avg_resolution_hours
# 2    hotline             39.333333
# 3  truc tiep             37.500000
# 4  trực tiếp             37.000000
# 0        app             28.173913
# 6    website             22.285714
# 1   hot line             21.142857
# 5   web site              6.000000

# %%
# 3.5 Xác định area hoặc department có thời gian xử lý cao bất thường
#Theo department
mean_hr = resolution_df['resolution_hours'].mean()
std_hr = resolution_df['resolution_hours'].std()

abnormal_threshold = mean_hr + 1.5 * std_hr

abnormal_departments = (
    feedback_resolution
    .groupby('department')['resolution_hours']
    .mean()
    .reset_index(name='avg_resolution_hours')
)

abnormal_departments = abnormal_departments[
    abnormal_departments['avg_resolution_hours'] > abnormal_threshold
]

abnormal_departments
# Out:
# Empty DataFrame
# Columns: [department, avg_resolution_hours]
# Index: []

# %%
#Theo area
feedback_area_resolution = feedback_area.merge(
    resolution_df[['feedback_id', 'resolution_hours']],
    on='feedback_id',
    how='left'
)

abnormal_areas = (
    feedback_area_resolution
    .groupby('area')['resolution_hours']
    .mean()
    .reset_index(name='avg_resolution_hours')
)

abnormal_areas = abnormal_areas[
    abnormal_areas['avg_resolution_hours'] > abnormal_threshold
]

abnormal_areas
# Out:
# Empty DataFrame
# Columns: [area, avg_resolution_hours]
# Index: []
